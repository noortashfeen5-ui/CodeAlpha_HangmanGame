# %% [markdown]
# <a href="https://colab.research.google.com/github/noortashfeen5-ui/CodeAlpha_HangmanGame/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to my Hangman Game!")
# Out:
# Welcome to my Hangman Game!

# %%
words = ["python", "computer", "biology", "coding", "science"]

# %%
import random

word = random.choice(words)

print(word)
# Out:
# computer

# %%
guessed_word = ["_"] * len(word)

print(" ".join(guessed_word))
# Out:
# _ _ _ _ _ _ _ _

# %%
guess = input("Guess a letter: ").lower()

print("You guessed:", guess)
# Out:
# Guess a letter: m
# You guessed: m

# %%
if guess in word:
    print("Correct guess!")
else:
    print("Wrong guess!")
# Out:
# Correct guess!

# %%
for i in range(len(word)):
    if word[i] == guess:
        guessed_word[i] = guess

print(" ".join(guessed_word))
# Out:
# _ _ m _ _ _ _ _

# %%
guess = "a"

wrong_guesses = 0

if guess not in word:
    wrong_guesses += 1

print("Wrong guesses:", wrong_guesses)
# Out:
# Wrong guesses: 1

# %%
wrong_guesses = 6

if wrong_guesses >= 6:
    print("Game Over!")
    print("The word was:", word)
# Out:
# Game Over!
# The word was: computer

# %%
if "_" not in guessed_word:
    print("Congratulations! You won!")

# %%
import random

# List of words
words = ["python", "computer", "biology", "coding", "science"]

# Choose a random word
word = random.choice(words)

# Create blanks
guessed_word = ["_"] * len(word)

# Store guessed letters
guessed_letters = []

# Count wrong guesses
wrong_guesses = 0
max_wrong_guesses = 6

print("Welcome to Hangman Game!")
print("You have 6 chances to guess the word.")
print("Word:", " ".join(guessed_word))

while wrong_guesses < max_wrong_guesses and "_" in guessed_word:

    guess = input("\nGuess a letter: ").lower()

    # Check if input is one letter
    if len(guess) != 1 or not guess.isalpha():
        print("Please enter one letter only.")
        continue

    # Check if letter was already guessed
    if guess in guessed_letters:
        print("You already guessed that letter.")
        continue

    guessed_letters.append(guess)

    # Check the guess
    if guess in word:
        print("Correct guess!")

        for i in range(len(word)):
            if word[i] == guess:
                guessed_word[i] = guess

    else:
        wrong_guesses += 1
        print("Wrong guess!")
        print("You have", max_wrong_guesses - wrong_guesses, "chances left.")

    print("Word:", " ".join(guessed_word))
    print("Wrong guesses:", wrong_guesses)

# Final result
if "_" not in guessed_word:
    print("\nCongratulations! You won!")
    print("The word was:", word)
else:
    print("\nGame Over!")
    print("The word was:", word)
# Out:
# Welcome to Hangman Game!
# You have 6 chances to guess the word.
# Word: _ _ _ _ _ _ _ _
#
# Guess a letter: m
# Correct guess!
# Word: _ _ m _ _ _ _ _
# Wrong guesses: 0
#
# Guess a letter: p
# Correct guess!
# Word: _ _ m p _ _ _ _
# Wrong guesses: 0
#
# Guess a letter: o
# Correct guess!
# Word: _ o m p _ _ _ _
# Wrong guesses: 0
#
# Guess a letter: c
# Correct guess!
# Word: c o m p _ _ _ _
# Wrong guesses: 0
#
# Guess a letter: u
# Correct guess!
# Word: c o m p u _ _ _
# Wrong guesses: 0
#
# Guess a letter: t
# Correct guess!
# Word: c o m p u t _ _
# Wrong guesses: 0
#
# Guess a letter: e
# Correct guess!
# Word: c o m p u t e _
# Wrong guesses: 0
#
# Guess a letter: r
# Correct guess!
# Word: c o m p u t e r
# Wrong guesses: 0
#
# Congratulations! You won!
# The word was: computer
